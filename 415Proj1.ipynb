# %% [markdown]
# # Project 1: Nonlinear Predator Prey
# ## Owen Connolly, John Kowalski, Niall Martin
# ### PHY 415
# ### 27 September 2024

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %% [markdown]
# Our differential system is...
#
# $$ \frac{dx}{dt} = \alpha x - \beta x y $$
#
# $$ \frac{dy}{dt} = -\gamma y +  \delta x y $$

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# Define the Lotka-Volterra equations
def lotka_volterra(t, z, alpha, beta, gamma, delta):
    x, y = z
    dxdt = alpha * x - beta * x * y
    dydt = -gamma * y + delta * x * y
    return [dxdt, dydt]

# Parameters
alpha = 1.0  # Prey birth rate
beta = 0.1   # Predator's rate of catching prey
gamma = 1.5  # Predator death rate
delta = 0.075 # Predator's efficiency at turning prey into new predators

# Initial populations
x0 = 40  # Initial prey population
y0 = 9   # Initial predator population
z0 = [x0, y0]

# Time span
t_span = (0, 200)
t_eval = np.linspace(0, 200, 1000)

# Solve the system
sol = solve_ivp(lotka_volterra, t_span, z0, args=(alpha, beta, gamma, delta), t_eval=t_eval)

# Plot the results
plt.plot(sol.t, sol.y[0], label='Prey (x)')
plt.plot(sol.t, sol.y[1], label='Predator (y)')
plt.xlabel('Time')
plt.ylabel('Population')
plt.legend()
plt.title('Predator-Prey Model (Lotka-Volterra)')
plt.show()
